# %%
#1. Import Pandas and check its version.
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
#2. Create a Series from a Python list [10, 20, 30, 40].
s = pd.Series([10, 20, 30, 40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#3. 
dict =     {"Name": ["A", "B"], 
            "Age": [20, 22]}
df = pd.DataFrame(dict)

# %%
df
# Out:
#   Name  Age
# 0    A   20
# 1    B   22

# %%
#4. Read a CSV file using Pandas.
df = pd.read_csv("../Data/Marks1.csv")

# %%
df
# Out:
#         Name School  Marks
# 0      Rahul     NR     34
# 1   Abhishek    VPS     56
# 2      Sohit    CPV     56
# 3      Harsh    JPS     66
# 4      Akash     NR     44
# 5  Divyanshu    JPS     55
# 6    Prateek     NR     78
# 7   UditKant     NR     98
# 8      Ayush    GPS     90

# %%
#5. Display the first 5 rows of a DataFrame.
df.head()
# Out:
#        Name School  Marks
# 0     Rahul     NR     34
# 1  Abhishek    VPS     56
# 2     Sohit    CPV     56
# 3     Harsh    JPS     66
# 4     Akash     NR     44

# %%
#6. Display the last 3 rows.
df.tail(3)
# Out:
#        Name School  Marks
# 6   Prateek     NR     78
# 7  UditKant     NR     98
# 8     Ayush    GPS     90

# %%
#7. Check: 1. shape 2. columns 3. data types
df.shape
# Out:
# (9, 3)

# %%
df.columns
# Out:
# Index(['Name', 'School', 'Marks'], dtype='object')

# %%
df.dtypes
# Out:
# Name      object
# School    object
# Marks      int64
# dtype: object

# %%
#8. Rename a column.
df.rename(columns = {"School" : "Vidyalay"}, inplace = True)

# %%
df
# Out:
#         Name Vidyalay  Marks
# 0      Rahul       NR     34
# 1   Abhishek      VPS     56
# 2      Sohit      CPV     56
# 3      Harsh      JPS     66
# 4      Akash       NR     44
# 5  Divyanshu      JPS     55
# 6    Prateek       NR     78
# 7   UditKant       NR     98
# 8      Ayush      GPS     90

# %%
#9. Set a column as the index.
df.set_index("Name", inplace=True)

# %%
df
# Out:
#           Vidyalay  Marks
# Name
# Rahul           NR     34
# Abhishek       VPS     56
# Sohit          CPV     56
# Harsh          JPS     66
# Akash           NR     44
# Divyanshu      JPS     55
# Prateek         NR     78
# UditKant        NR     98
# Ayush          GPS     90

# %%
#10. Reset the index.
df.reset_index(inplace = True)

# %%
df
# Out:
#         Name Vidyalay  Marks
# 0      Rahul       NR     34
# 1   Abhishek      VPS     56
# 2      Sohit      CPV     56
# 3      Harsh      JPS     66
# 4      Akash       NR     44
# 5  Divyanshu      JPS     55
# 6    Prateek       NR     78
# 7   UditKant       NR     98
# 8      Ayush      GPS     90
