# %% [markdown]
# # Pandas Installation & Environment Setup

# %% [markdown]
# This notebook explains how to install Pandas and verifies
# that the environment is set up correctly for data analysis.

# %% [markdown]
# # Install pandas using pip
# pip install pandas
#
# #or if you are using Anaconda
# # Install pandas using conda
# conda install pandas

# %%
import pandas as pd
pd.__version__

#This proves Pandas is installed.
# Out:
# '2.3.3'

# %%
#Here is small example-
df = pd.DataFrame({
    "Name": ["A", "B", "C"],
    "Age": [20, 21, 22]
})

df
# Out:
#   Name  Age
# 0    A   20
# 1    B   21
# 2    C   22
