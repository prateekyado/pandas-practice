# %% [markdown]
# Pandas is built on two main data structures:
#
#     Series → One-dimensional (like a single column in Excel)
#     DataFrame → Two-dimensional (like a full spreadsheet or SQL table)

# %%
import pandas as pd

# %%
#Series
s = pd.Series([89, 55, 77, 99])

# %%
s
# Out:
# 0    89
# 1    55
# 2    77
# 3    99
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([89, 55, 77, 99], index=["Rahul", "Divyanshu", "Prateek", "Harsh"])

# %%
s2
# Out:
# Rahul        89
# Divyanshu    55
# Prateek      77
# Harsh        99
# dtype: int64

# %%
s2["Rahul"]
# Out:
# np.int64(89)

# %% [markdown]
# A DataFrame is like a dictionary of Series — multiple columns with labels.

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
